# %% [markdown]
# # basic python assignment
#
# 1.What is Python, and why is it popular
#  - Python is a high-level, interpreted programming language known for its readability and versatility. Popular due to its simple syntax, extensive libraries, and wide range of applications like web development, data science, AI.
#
# 2.What is an interpreter in Python
#   - An interpreter executes Python code line by line, translating it into machine code at runtime.
#
# 3.What are pre-defined keywords in Python
#   - Reserved words with special meanings that cannot be used as identifiers like if, else, for, while, def, class.
#
# 4.Can keywords be used as variable names
#  - No, keywords cannot be used as variable names.
# What is mutability in Python? Mutability refers to whether an object's state can be modified after it's created. Mutable objects can be changed, immutable objects cannot.
#
# 5.What is mutability in Python
#  - Mutability refers to whether an object's state can be modified after it's created. Mutable objects can be changed, immutable objects cannot.
#
# 6.Why are lists mutable, but tuples are immutable
#  - Lists are designed for dynamic collections where elements can be added, removed, or changed. Tuples are designed for fixed collections where the elements should not change after creation, offering data integrity and sometimes better performance.
#
# 7.What is the difference between “==” and “is” operators in Python
#  -  == checks for value equality like if two objects have the same content. is checks for identity equality like if two variables refer to the exact same object in memory.
#
# 8.What are logical operators in Python
#  - Operators used to combine conditional statements: and, or, not.
#
# 9.What is type casting in Python
#  - Explicitly converting a variable from one data type to another like  int, str, float.
#
# 10.What is the difference between implicit and explicit type casting
#  - Implicit : Python automatically converts data types during an operation
# Explicit : The programmer explicitly converts data types using built-in functions.
#
# 11.What is the purpose of conditional statements in Python
#  - To execute different blocks of code based on whether a specified condition is true or false. e.g: if, elif, else.
#
# 12.How does the elif statement work
# - elif (else if) allows you to check multiple conditions sequentially. If the preceding if or elif conditions are false, the elif condition is evaluated.
#
#
# 13.What is the difference between for and while loops
#  - for loop: Used for iterating over a sequence (list, tuple, string, range) or other iterable objects a predetermined number of times.
# while loop: Used for repeatedly executing a block of code as long as a specified condition is true. The number of iterations is not typically known beforehand.
#
# 14.Describe a scenario where a while loop is more suitable than a for loop
#  -  A while loop is more suitable when you need to repeat an action until a certain condition is met, and you don't know in advance how many times that action will need to be performed. For example, reading user input until a valid input is provided, or in a game loop that continues until the game ends.

# %%
# 1.Write a Python program to print "Hello, World!"
'''
print("Hello, World!")
'''
# 2.Write a Python program that displays your name and age.
'''
name = "Your Name"
age = 30 # or your actual age
printf("My name is {name} and I am {age} years old.")
'''
# 3.Write code to print all the pre-defined keywords in Python using the keyword library.
'''
import keyword
print(keyword.kwlist)
'''
# 4.Write a program that checks if a given word is a Python keyword.
'''
import keyword
word = "if" # example word
if word in keyword.kwlist:
    print(f"'{word}' is a Python keyword.")
else:
    print(f"'{word}' is not a Python keyword.")
'''
# 5.Create a list and tuple in Python, and demonstrate how attempting to change an element works for each.
'''
my_list = [1, 2, 3]
print(f"Original list: {my_list}")
my_list[0] = 10
print(f"Modified list: {my_list}")

my_tuple = (1, 2, 3)
print(f"Original tuple: {my_tuple}")
try:
    my_tuple[0] = 10
except TypeError as e:
    print(f"Error when trying to modify tuple: {e}")
'''
# 6.Write a function to demonstrate the behavior of mutable and immutable arguments.
'''
def modify_mutable(a_list):
    a_list.append(4)

def modify_immutable(an_int):
    an_int += 1

my_list = [1, 2, 3]
my_int = 5

print(f"Before: List={my_list}, Int={my_int}")
modify_mutable(my_list)
modify_immutable(my_int)
print(f"After: List={my_list}, Int={my_int}")
'''
# 7.Write a program that performs basic arithmetic operations on two user-input numbers.
'''
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print(f"Sum: {num1 + num2}")
print(f"Difference: {num1 - num2}")
print(f"Product: {num1 * num2}")
if num2 != 0:
    print(f"Division: {num1 / num2}")
else:
    print("Division by zero is not allowed.")
'''
# 8.Write a program to demonstrate the use of logical operators.
'''
age = 25
has_license = True

if age >= 18 and has_license:
    print("Eligible to drive.")
else:
    print("Not eligible to drive.")

is_weekend = False
is_holiday = True

if is_weekend or is_holiday:
    print("It's a free day!")
else:
    print("It's a workday.")

is_raining = True
if not is_raining:
    print("Let's go outside!")
else:
    print("Better stay indoors.")
'''
# 9.Write a Python program to convert user input from string to integer, float, and boolean types.
'''
str_input = input("Enter something: ")

try:
    int_val = int(str_input)
    print(f"As integer: {int_val} (Type: {type(int_val)})")
except ValueError:
    print(f"Cannot convert '{str_input}' to integer.")

try:
    float_val = float(str_input)
    print(f"As float: {float_val} (Type: {type(float_val)})")
except ValueError:
    print(f"Cannot convert '{str_input}' to float.")

bool_val = str_input.lower() in ('true', '1', 'yes') # Example logic
print(f"As boolean: {bool_val} (Type: {type(bool_val)})")
'''
# 10.Write code to demonstrate type casting with list elements.
'''
str_numbers = ["1", "2", "3", "4"]
int_numbers = [int(num) for num in str_numbers]
print(f"String numbers: {str_numbers}")
print(f"Integer numbers: {int_numbers}")

mixed_list = [10, "20", 30.5]
str_mixed_list = [str(item) for item in mixed_list]
print(f"Mixed list: {mixed_list}")
print(f"Mixed list as strings: {str_mixed_list}")
'''
# 11.Write a program that checks if a number is positive, negative, or zero.
'''
number = float(input("Enter a number: "))
if number > 0:
    print("The number is positive.")
elif number < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
'''
# 12.Write code for loop to print numbers from 1 to 10.
'''
for i in range(1, 11):
    print(i)
'''
# 13.Write a Python program to find the sum of all even numbers between 1 and 50.
'''
total_sum = 0
for i in range(2, 51, 2): # Start from 2, end at 50, step by 2
    total_sum += i
print(f"The sum of even numbers between 1 and 50 is: {total_sum}")
'''
# 14.Write a program to reverse a string using a while loop.
'''
s = "Python"
reversed_s = ""
index = len(s) - 1
while index >= 0:
    reversed_s += s[index]
    index -= 1
print(f"Original string: {s}")
print(f"Reversed string: {reversed_s}")

'''
# 15.Write a Python program to calculate the factorial of a number provided by the user using a while loop.
'''
num = int(input("Enter a non-negative integer: "))
factorial = 1
if num < 0:
    print("Factorial is not defined for negative numbers.")
elif num == 0:
    print("The factorial of 0 is 1.")
else:
    i = 1
    while i <= num:
        factorial *= i
        i += 1
    print(f"The factorial of {num} is {factorial}.")
'''
